# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.impute import MissingIndicator,SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,classification_report, average_precision_score, precision_recall_curve
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
dataset = pd.read_csv("Fraud")

# %%
dataset
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0
#
# [6362620 rows x 11 columns]

# %% [markdown]
# # Data Understanding

# %%
df = pd.DataFrame(dataset)

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df['isFlaggedFraud'].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %% [markdown]
# # Memory Optimization.

# %%
df.memory_usage(deep=True).sum() / 1e6   # Before.
# Out:
# 1523.125282

# %%
for col in df.select_dtypes(include='int'):
    df[col] = pd.to_numeric(df[col], downcast='integer')

for col in df.select_dtypes(include='float'):
    df[col] = pd.to_numeric(df[col], downcast='float')

# %%
df.memory_usage(deep=True).sum() / 1e6    # After.
# Out:
# 1395.872882

# %% [markdown]
# # 1 Data Cleaning (Missing values, Outliers, Multicollinearity).

# %%
# In this Dataset the receiver's name whose name starts with M have no data in before and after receiving a money, 
# it does not mean
# that Merchant had no money , so it's simply indicating the missing value.
# In short oldbalanceDest and newbalanceDest are zero doesn't have zero money --> they indicates the missing values

# %%
df['dest_balance_missing'] = (df['oldbalanceDest'] == 0) & (df['newbalanceDest'] == 0)     # Instead of dropping , we preserve it because missing 
# values indicates strong detection.

# %%
df['dest_is_merchant'] = df['nameDest'].str.startswith('M').astype(int)  # creating a column for merchant for indication merchant account is empty.

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud  dest_balance_missing  dest_is_merchant
# 0                     0                  True                 1
# 1                     0                  True                 1
# 2                     0                  True                 0
# 3                     0                 False                 0
# 4                     0                  True                 1
# ...                 ...                   ...               ...
# 6362615               0                 False                 0
# 6362616               0                  True                 0
# 6362617               0                 False                 0
# 6362618               0                  True                 0
# 6362619               0                 False                 0
#
# [6362620 rows x 13 columns]

# %%
# Outliers.
# %matplotlib inline

# %%
df1 = df[['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']].skew() # measuring the skewness.
# Out:
# amount            30.993949
# oldbalanceOrg      5.249136
# newbalanceOrig     5.176884
# oldbalanceDest    19.921758
# newbalanceDest    19.352302
# dtype: float64

# %%
# Since the columns in below are right skewed --> we apply log transformation.

# %%
import numpy as np

cols = ['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']
for col in cols:
    df[col + '_log'] = np.log1p(df[col])

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud  dest_balance_missing  dest_is_merchant  amount_log  \
# 0                     0                  True                 1    9.194276
# 1                     0                  True                 1    7.531166
# 2                     0                  True                 0    5.204007
# 3                     0                 False                 0    5.204007
# 4                     0                  True                 1    9.364703
# ...                 ...                   ...               ...         ...
# 6362615               0                 False                 0   12.735768
# 6362616               0                  True                 0   15.657870
# 6362617               0                 False                 0   15.657870
# 6362618               0                  True                 0   13.652996
# 6362619               0                 False                 0   13.652996
#
#          oldbalanceOrg_log  newbalanceOrig_log  oldbalanceDest_log  \
# 0                12.044359           11.984786            0.000000
# 1                 9.964112            9.872292            0.000000
# 2                 5.204007            0.000000            0.000000
# 3                 5.204007            0.000000            9.960954
# 4                10.634773           10.305174            0.000000
# ...                    ...                 ...                 ...
# 6362615          12.735768            0.000000            0.000000
# 6362616          15.657870            0.000000            0.000000
# 6362617          15.657870            0.000000           11.134441
# 6362618          13.652996            0.000000            0.000000
# 6362619          13.652996            0.000000           15.688865
#
#          newbalanceDest_log
# 0                  0.000000
# 1                  0.000000
# 2                  0.000000
# 3                  0.000000
# 4                  0.000000
# ...                     ...
# 6362615           12.735768
# 6362616            0.000000
# 6362617           15.668663
# 6362618            0.000000
# 6362619           15.811584
#
# [6362620 rows x 18 columns]

# %%
for col in cols:                              # its better to do capping instead of removing the outliers beacause outliers are important for detecting fraud signals.
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df[col + '_log_capped'] = df[col + '_log'].clip(lower=np.log1p(lower), upper=np.log1p(upper))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26500\2104297207.py:7: RuntimeWarning: invalid value encountered in log1p
#   df[col + '_log_capped'] = df[col + '_log'].clip(lower=np.log1p(lower), upper=np.log1p(upper))
# C:\Users\hp\AppData\Local\Temp\ipykernel_26500\2104297207.py:7: RuntimeWarning: invalid value encountered in log1p
#   df[col + '_log_capped'] = df[col + '_log'].clip(lower=np.log1p(lower), upper=np.log1p(upper))
# C:\Users\hp\AppData\Local\Temp\ipykernel_26500\2104297207.py:7: RuntimeWarning: invalid value encountered in log1p
#   df[col + '_log_capped'] = df[col + '_log'].clip(lower=np.log1p(lower), upper=np.log1p(upper))
# C:\Users\hp\AppData\Local\Temp\ipykernel_26500\2104297207.py:7: RuntimeWarning: invalid value encountered in log1p
#   df[col + '_log_capped'] = df[col + '_log'].clip(lower=np.log1p(lower), upper=np.log1p(upper))
# C:\Users\hp\AppData\Local\Temp\ipykernel_26500\2104297207.py:7: RuntimeWarning: invalid value encountered in log1p
#   df[col + '_log_capped'] = df[col + '_log'].clip(lower=np.log1p(lower), upper=np.log1p(upper))

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          ...  amount_log  oldbalanceOrg_log  newbalanceOrig_log  \
# 0        ...    9.194276          12.044359           11.984786
# 1        ...    7.531166           9.964112            9.872292
# 2        ...    5.204007           5.204007            0.000000
# 3        ...    5.204007           5.204007            0.000000
# 4        ...    9.364703          10.634773           10.305174
# ...      ...         ...                ...                 ...
# 6362615  ...   12.735768          12.735768            0.000000
# 6362616  ...   15.657870          15.657870            0.000000
# 6362617  ...   15.657870          15.657870            0.000000
# 6362618  ...   13.652996          13.652996            0.000000
# 6362619  ...   13.652996          13.652996            0.000000
#
#          oldbalanceDest_log  newbalanceDest_log  amount_log_capped  \
# 0                  0.000000            0.000000           9.194276
# 1                  0.000000            0.000000           7.531166
# 2                  0.000000            0.000000           5.204007
# 3                  9.960954            0.000000           5.204007
# 4                  0.000000            0.000000           9.364703
# ...                     ...                 ...                ...
# 6362615            0.000000           12.735768          12.735768
# 6362616            0.000000            0.000000          13.125798
# 6362617           11.134441           15.668663          13.125798
# 6362618            0.000000            0.000000          13.125798
# 6362619           15.688865           15.811584          13.125798
#
#          oldbalanceOrg_log_capped  newbalanceOrig_log_capped  \
# 0                       12.044359                  11.984786
# 1                        9.964112                   9.872292
# 2                        5.204007                   0.000000
# 3                        5.204007                   0.000000
# 4                       10.634773                  10.305174
# ...                           ...                        ...
# 6362615                 12.499820                   0.000000
# 6362616                 12.499820                   0.000000
# 6362617                 12.499820                   0.000000
# 6362618                 12.499820                   0.000000
# 6362619                 12.499820                   0.000000
#
#          oldbalanceDest_log_capped  newbalanceDest_log_capped
# 0                         0.000000                   0.000000
# 1                         0.000000                   0.000000
# 2                         0.000000                   0.000000
# 3                         9.960954                   0.000000
# 4                         0.000000                   0.000000
# ...                            ...                        ...
# 6362615                   0.000000                  12.735768
# 6362616                   0.000000                   0.000000
# 6362617                  11.134441                  14.837880
# 6362618                   0.000000                   0.000000
# 6362619                  14.673152                  14.837880
#
# [6362620 rows x 23 columns]

# %%
# No use of these columns given below.

# %%
df.drop(columns = ['amount_log','oldbalanceOrg_log','newbalanceOrig_log','oldbalanceDest_log','newbalanceDest_log','step'],inplace = True)

# %%
# Here, it is checking the multicollinearity of dataset columns by using two methods: 1) correlation 2) Varinace Inflation factor(VIF).
# Those having strong correlation and VIF > 5 or 10 should be remove to decrease multicollinearity of dataset.

# %%
sns.set(style = "whitegrid", palette = "coolwarm")
df1 = df[['amount','oldbalanceOrg'	,'newbalanceOrig' ,'oldbalanceDest'	,'newbalanceDest'	,'isFraud'	,'isFlaggedFraud'	,'dest_is_merchant'	,'amount_log_capped'	,'oldbalanceOrg_log_capped'	,'newbalanceOrig_log_capped'	,'oldbalanceDest_log_capped'	,'newbalanceDest_log_capped']]
corr_matrix = df1.corr()

plt.figure(figsize = (7,5))
sns.heatmap(corr_matrix, annot = True, cmap = "coolwarm", fmt = ".2f" , linewidth = 0.5)
plt.title("Correlation Heatmap of Fraud detection data", fontsize = 14, weight = 'bold')
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

X = df[['amount','oldbalanceOrg'	,'newbalanceOrig' ,'oldbalanceDest'	,'newbalanceDest'	,'isFraud'	,'isFlaggedFraud'	,'dest_is_merchant'	,'amount_log_capped'	,'oldbalanceOrg_log_capped'	,'newbalanceOrig_log_capped'	,'oldbalanceDest_log_capped'	,'newbalanceDest_log_capped']]
vif = pd.DataFrame()
vif['Feature'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#                       Feature         VIF
# 0                      amount    4.328472
# 1               oldbalanceOrg  665.782203
# 2              newbalanceOrig  674.791058
# 3              oldbalanceDest   75.201429
# 4              newbalanceDest   87.119149
# 5                     isFraud    1.227714
# 6              isFlaggedFraud    1.002633
# 7            dest_is_merchant    5.088363
# 8           amount_log_capped   20.820944
# 9    oldbalanceOrg_log_capped    6.972676
# 10  newbalanceOrig_log_capped    5.106260
# 11  oldbalanceDest_log_capped   12.326380
# 12  newbalanceDest_log_capped   21.996810

# %%
df['orig_balance_change'] = df['oldbalanceOrg'] - df['newbalanceOrig']
df['dest_balance_change'] = df['newbalanceDest'] - df['oldbalanceDest']

# %%
drop_cols = [
    'oldbalanceOrg', 'newbalanceOrig',
    'oldbalanceDest', 'newbalanceDest'
]
df = df.drop(columns=drop_cols)

# %%
df = df.drop(columns=[
    'newbalanceOrig_log_capped',
    'newbalanceDest_log_capped'
])

# %%
df
# Out:
#              type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0         PAYMENT     9839.64  C1231006815      170136.00       160296.36
# 1         PAYMENT     1864.28  C1666544295       21249.00        19384.72
# 2        TRANSFER      181.00  C1305486145         181.00            0.00
# 3        CASH_OUT      181.00   C840083671         181.00            0.00
# 4         PAYMENT    11668.14  C2048537720       41554.00        29885.86
# ...           ...         ...          ...            ...             ...
# 6362615  CASH_OUT   339682.13   C786484425      339682.13            0.00
# 6362616  TRANSFER  6311409.28  C1529008245     6311409.28            0.00
# 6362617  CASH_OUT  6311409.28  C1162922333     6311409.28            0.00
# 6362618  TRANSFER   850002.52  C1685995037      850002.52            0.00
# 6362619  CASH_OUT   850002.52  C1280323807      850002.52            0.00
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0        M1979787155            0.00            0.00        0               0
# 1        M2044282225            0.00            0.00        0               0
# 2         C553264065            0.00            0.00        1               0
# 3          C38997010        21182.00            0.00        1               0
# 4        M1230701703            0.00            0.00        0               0
# ...              ...             ...             ...      ...             ...
# 6362615   C776919290            0.00       339682.13        1               0
# 6362616  C1881841831            0.00            0.00        1               0
# 6362617  C1365125890        68488.84      6379898.11        1               0
# 6362618  C2080388513            0.00            0.00        1               0
# 6362619   C873221189      6510099.11      7360101.63        1               0
#
#          dest_balance_missing  dest_is_merchant  amount_log_capped  \
# 0                        True                 1           9.194276
# 1                        True                 1           7.531166
# 2                        True                 0           5.204007
# 3                       False                 0           5.204007
# 4                        True                 1           9.364703
# ...                       ...               ...                ...
# 6362615                 False                 0          12.735768
# 6362616                  True                 0          13.125798
# 6362617                 False                 0          13.125798
# 6362618                  True                 0          13.125798
# 6362619                 False                 0          13.125798
#
#          oldbalanceOrg_log_capped  oldbalanceDest_log_capped  \
# 0                       12.044359                   0.000000
# 1                        9.964112                   0.000000
# 2                        5.204007                   0.000000
# 3                        5.204007                   9.960954
# 4                       10.634773                   0.000000
# ...                           ...                        ...
# 6362615                 12.499820                   0.000000
# 6362616                 12.499820                   0.000000
# 6362617                 12.499820                  11.134441
# 6362618                 12.499820                   0.000000
# 6362619                 12.499820                  14.673152
#
#          orig_balance_change  dest_balance_change
# 0                    9839.64                 0.00
# 1                    1864.28                 0.00
# 2                     181.00                 0.00
# 3                     181.00            -21182.00
# 4                   11668.14                 0.00
# ...                      ...                  ...
# 6362615            339682.13            339682.13
# 6362616           6311409.28                 0.00
# 6362617           6311409.28           6311409.27
# 6362618            850002.52                 0.00
# 6362619            850002.52            850002.52
#
# [6362620 rows x 17 columns]

# %%
# After creating new columns as well as dropping highly dependent columns VIF and correlation becomes better for our future training of models. 

X = df[['amount' ,'isFraud'	,'isFlaggedFraud','dest_is_merchant','amount_log_capped','oldbalanceOrg_log_capped'	,'oldbalanceDest_log_capped','orig_balance_change','dest_balance_change']]
vif1 = pd.DataFrame()
vif1['Feature'] = X.columns
vif1['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif1)
# Out:
#                      Feature        VIF
# 0                     amount   4.138930
# 1                    isFraud   1.190922
# 2             isFlaggedFraud   1.002597
# 3           dest_is_merchant   3.033264
# 4          amount_log_capped  11.572913
# 5   oldbalanceOrg_log_capped   2.879648
# 6  oldbalanceDest_log_capped   6.741434
# 7        orig_balance_change   1.278161
# 8        dest_balance_change   3.831884

# %%
sns.set(style = "whitegrid", palette = "coolwarm")
df1 = df[['amount' ,'isFraud'	,'isFlaggedFraud','dest_is_merchant','amount_log_capped','oldbalanceOrg_log_capped'	,'oldbalanceDest_log_capped','orig_balance_change','dest_balance_change']]
corr_matrix = df1.corr()

plt.figure(figsize = (7,5))
sns.heatmap(corr_matrix, annot = True, cmap = "coolwarm", fmt = ".2f" , linewidth = 0.5)
plt.title("Correlation Heatmap of Fraud detection data", fontsize = 14, weight = 'bold')
plt.show()

# %% [markdown]
# # 3) Fraud Detection Model (Detailed)

# %%
# By dropping some more features...our dataset looks like given below , since their is no use of the name columns for what our aim is.
# We used an XGBoost Classifier, because:

# Handles large-scale, imbalanced data well.

# Captures non-linear relationships.
# Variable Selection

# We selected variables based on:

# Business logic (transaction amount, balances, type)

# Correlation analysis

# Feature importance from model

# Avoiding data leakage (excluded isFlaggedFraud from predictors
# Final important variables:

# amount
# type

# oldbalanceOrg, newbalanceOrig

# oldbalanceDest, newbalanceDest

# dest_balance_missing

# balance_diff

# %%
df_baseline = df.drop(columns=['nameOrig', 'nameDest'])

# %%
df_baseline
# Out:
#              type      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0         PAYMENT     9839.64      170136.00       160296.36            0.00
# 1         PAYMENT     1864.28       21249.00        19384.72            0.00
# 2        TRANSFER      181.00         181.00            0.00            0.00
# 3        CASH_OUT      181.00         181.00            0.00        21182.00
# 4         PAYMENT    11668.14       41554.00        29885.86            0.00
# ...           ...         ...            ...             ...             ...
# 6362615  CASH_OUT   339682.13      339682.13            0.00            0.00
# 6362616  TRANSFER  6311409.28     6311409.28            0.00            0.00
# 6362617  CASH_OUT  6311409.28     6311409.28            0.00        68488.84
# 6362618  TRANSFER   850002.52      850002.52            0.00            0.00
# 6362619  CASH_OUT   850002.52      850002.52            0.00      6510099.11
#
#          newbalanceDest  isFraud  isFlaggedFraud  dest_balance_missing  \
# 0                  0.00        0               0                  True
# 1                  0.00        0               0                  True
# 2                  0.00        1               0                  True
# 3                  0.00        1               0                 False
# 4                  0.00        0               0                  True
# ...                 ...      ...             ...                   ...
# 6362615       339682.13        1               0                 False
# 6362616            0.00        1               0                  True
# 6362617      6379898.11        1               0                 False
# 6362618            0.00        1               0                  True
# 6362619      7360101.63        1               0                 False
#
#          dest_is_merchant  amount_log_capped  oldbalanceOrg_log_capped  \
# 0                       1           9.194276                 12.044359
# 1                       1           7.531166                  9.964112
# 2                       0           5.204007                  5.204007
# 3                       0           5.204007                  5.204007
# 4                       1           9.364703                 10.634773
# ...                   ...                ...                       ...
# 6362615                 0          12.735768                 12.499820
# 6362616                 0          13.125798                 12.499820
# 6362617                 0          13.125798                 12.499820
# 6362618                 0          13.125798                 12.499820
# 6362619                 0          13.125798                 12.499820
#
#          oldbalanceDest_log_capped  orig_balance_change  dest_balance_change
# 0                         0.000000              9839.64                 0.00
# 1                         0.000000              1864.28                 0.00
# 2                         0.000000               181.00                 0.00
# 3                         9.960954               181.00            -21182.00
# 4                         0.000000             11668.14                 0.00
# ...                            ...                  ...                  ...
# 6362615                   0.000000            339682.13            339682.13
# 6362616                   0.000000           6311409.28                 0.00
# 6362617                  11.134441           6311409.28           6311409.27
# 6362618                   0.000000            850002.52                 0.00
# 6362619                  14.673152            850002.52            850002.52
#
# [6362620 rows x 15 columns]

# %%
X = df_baseline.drop(['isFraud'],axis = 1)
y = df_baseline['isFraud']

# %%
categorical_features = ['type','dest_balance_missing']

preprocessor = ColumnTransformer(
    transformers = [
        ('cat', OneHotEncoder(drop = 'first', handle_unknown = 'ignore'), categorical_features)
    ],
    remainder = 'passthrough'
)    
X_encoded = preprocessor.fit_transform(X)

# %%
# Model Training.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded , y , test_size = 0.2, random_state = 42, stratify=y)

# %%
# Baseline Line Model

# %%
from sklearn.linear_model import SGDClassifier

model = SGDClassifier(
    loss='log_loss',        # Logistic Regression
    penalty='l2',           # Regularization.
    alpha=0.0001,           # Regularization strength (default & safe)
    learning_rate='optimal',
    max_iter=2000,          # Enough for convergence on large data
    tol=1e-3,               # Stops early if converged.
    class_weight='balanced',# Handles class imbalance
    n_jobs=-1,              # Use all CPU cores
    random_state=41
)

# %% [markdown]
# # 4) Model Performance Evaluation
# # We used multiple metrics due to class imbalance:

# %%
 Metric     Why Used                        

 Recall     Catch as much fraud as possible 
 Precision  Avoid too many false alarms     
 PR-AUC     Best metric for rare fraud      
 ROC-AUC    Measures ranking quality

# %%
model.fit(X_train , y_train)

y_pred = model.predict(X_test)
print("Accuracy Score", accuracy_score(y_test,y_pred))
print("ROC-AUC-SCORE", roc_auc_score(y_test, y_pred))
# Out:
# Accuracy Score 0.7904770361894943
# ROC-AUC-SCORE 0.885857523755036

# %%
print("Precision Score", precision_score(y_test, y_pred))
print("Recall Score", recall_score(y_test, y_pred))
# Out:
# Precision Score 0.005928787432462162
# Recall Score 0.9814814814814815

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: xgboost in c:\users\hp\appdata\roaming\python\python312\site-packages (3.1.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\hp\appdata\roaming\python\python312\site-packages (from xgboost) (1.16.3)

# %%
from xgboost import XGBClassifier
scale_pos_weight = (y == 0).sum() / (y == 1).sum()

# %%
model1 = XGBClassifier(
    n_estimators=800,
    max_depth=10,
    learning_rate=0.01,
    subsample=0.9,
    colsample_bytree=0.9,
    objective='binary:logistic',
    eval_metric='aucpr',
    tree_method='hist',          # Fast & memory efficient
    max_bin=256,
    min_child_weight = 5,
    scale_pos_weight=scale_pos_weight,
    n_jobs = -1,
    gamma = 0.5,
    reg_lambda = 1.5,
    random_state=41
)

# %%
model1.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='aucpr', feature_types=None,
#               feature_weights=None, gamma=0.5, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.01, max_bin=256, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=10,
#               max_leaves=None, min_child_weight=5, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=800,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
# Checking Wheather data is balanced or imbalanced.

# %%
df_baseline['isFraud'].value_counts(normalize=True) * 100
# Out:
# isFraud
# 0    99.870918
# 1     0.129082
# Name: proportion, dtype: float64

# %%
y_pred1 = model1.predict(X_test)
print("Accuracy Score", accuracy_score(y_test,y_pred1))
print("ROC-AUC-SCORE", roc_auc_score(y_test, y_pred1))
# Out:
# Accuracy Score 0.9928850064910367
# ROC-AUC-SCORE 0.9891436336477524

# %%
print("Recall Score", recall_score(y_test, y_pred1))
y_proba = model1.predict_proba(X_test)[:, 1]
pr_auc = average_precision_score(y_test, y_proba)
print("PR-AUC:", pr_auc)     # Since Data is umbalanced type so, we can take a precision - recall - auc metric.
# Out:
# Recall Score 0.985392574558734
# PR-AUC: 0.8433514069289522

# %%
# Since Recall, PR-AUC and ROC-AUC score are very important metrics . According to our aim, we have to acheive 
# 98 --> percent recall, 98 percantage --> ROC-AUC and 84 percent --> PR-AUC(Precision-Recall -AUC).

# %%
# Plotting Precision - Recall Curve

# %%
precision, recall, _ = precision_recall_curve(y_test, y_proba)
plt.figure(figsize = (7,5))
plt.plot(recall, precision, label = f"PR-AUC = {pr_auc:.3f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

y_pred = (y_proba >= 0.5).astype(int)  # You can change threshold

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Not Fraud", "Fraud"])

disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ️ Key Factors Predicting Fraud

# %% [markdown]
# # 5) Key Factors Predicting Fraud

# %%
️# Key Factors Predicting Fraud

# Top fraud indicators:

# High transaction amount

# TRANSFER and CASH_OUT transaction types

# Zero destination balance before transaction

# Full account balance drained

# Balance mismatch (old − new ≠ amount)

# %% [markdown]
# # 6) Do These Factors Make Sense?

# %%
#Fraudsters:

#Drain accounts completely.

#Transfer money to newly created or empty accounts.

#Prefer TRANSFER → CASH_OUT patterns.

#Create balance inconsistencies due to system manipulation.

# %% [markdown]
# # 7) Prevention Strategies for Infrastructure Update

# %%
#Prevention Strategies for Infrastructure Update
 #Technical Controls

#Real-time fraud scoring on:

#Large transfers

#Sudden balance drops

#Zero-balance destination accounts

#Threshold-based transaction blocking.

#Multi-factor authentication for high-risk transactions.

#Policy Controls

#Daily transfer limits.

#Delayed settlement for suspicious transactions.

#Auto-freeze on repeated high-risk behavior.

# %% [markdown]
# # 8) How to Measure If Prevention Works

# %%
 Measure                 Goal              

 Fraud loss per day       Decrease        
 Fraud detection recall   Increase        
 False positive rate      Stable or lower 
 Customer complaints      Decrease        

#Also:

#Monitor PR-AUC over time

#Perform A/B testing on fraud rules

#Audit blocked vs confirmed fraud cases
